# %% [markdown]
# ## Observations and Insights

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import scipy.stats as st
import numpy as np

# Study data files
mouse_metadata_path = "data/Mouse_metadata.csv"
study_results_path = "data/Study_results.csv"

# Read the mouse data and the study results
mouse_metadata = pd.read_csv(mouse_metadata_path)
study_results = pd.read_csv(study_results_path)

# Combine the data into a single dataset
combined_mouse_df = pd.merge(mouse_metadata, study_results, how="inner", on="Mouse ID")
combined_mouse_df

# Display the data table for preview
# Out:
#      Mouse ID Drug Regimen   Sex  Age_months  Weight (g)  Timepoint  \
# 0        k403     Ramicane  Male          21          16          0
# 1        k403     Ramicane  Male          21          16          5
# 2        k403     Ramicane  Male          21          16         10
# 3        k403     Ramicane  Male          21          16         15
# 4        k403     Ramicane  Male          21          16         20
# ...       ...          ...   ...         ...         ...        ...
# 1888     z969     Naftisol  Male           9          30         25
# 1889     z969     Naftisol  Male           9          30         30
# 1890     z969     Naftisol  Male           9          30         35
# 1891     z969     Naftisol  Male           9          30         40
# 1892     z969     Naftisol  Male           9          30         45
#
#       Tumor Volume (mm3)  Metastatic Sites
# 0              45.000000                 0
# 1              38.825898                 0
# ...

# %%
# Checking the number of mice.
mouse_count = combined_mouse_df["Mouse ID"].count()
mouse_count
# Out:
# 1893

# %%
# Getting the duplicate mice by ID number that shows up for Mouse ID and Timepoint. 
duplicate_rows = combined_mouse_df[combined_mouse_df.duplicated(['Mouse ID', 'Timepoint'])]
duplicate_rows
# Out:
#     Mouse ID Drug Regimen     Sex  Age_months  Weight (g)  Timepoint  \
# 909     g989     Propriva  Female          21          26          0
# 911     g989     Propriva  Female          21          26          5
# 913     g989     Propriva  Female          21          26         10
# 915     g989     Propriva  Female          21          26         15
# 917     g989     Propriva  Female          21          26         20
#
#      Tumor Volume (mm3)  Metastatic Sites
# 909           45.000000                 0
# 911           47.570392                 0
# 913           49.880528                 0
# 915           53.442020                 0
# 917           54.657650                 1

# %%
# Optional: Get all the data for the duplicate mouse ID. 
all_duplicate_rows = combined_mouse_df[combined_mouse_df.duplicated(['Mouse ID',])]
all_duplicate_rows
# Out:
#      Mouse ID Drug Regimen   Sex  Age_months  Weight (g)  Timepoint  \
# 1        k403     Ramicane  Male          21          16          5
# 2        k403     Ramicane  Male          21          16         10
# 3        k403     Ramicane  Male          21          16         15
# 4        k403     Ramicane  Male          21          16         20
# 5        k403     Ramicane  Male          21          16         25
# ...       ...          ...   ...         ...         ...        ...
# 1888     z969     Naftisol  Male           9          30         25
# 1889     z969     Naftisol  Male           9          30         30
# 1890     z969     Naftisol  Male           9          30         35
# 1891     z969     Naftisol  Male           9          30         40
# 1892     z969     Naftisol  Male           9          30         45
#
#       Tumor Volume (mm3)  Metastatic Sites
# 1              38.825898                 0
# 2              35.014271                 1
# ...

# %%
# Create a clean DataFrame by dropping the duplicate mouse by its ID.
clean_mouse_df = combined_mouse_df.drop_duplicates("Mouse ID")
clean_mouse_df
# Out:
#      Mouse ID Drug Regimen     Sex  Age_months  Weight (g)  Timepoint  \
# 0        k403     Ramicane    Male          21          16          0
# 10       s185    Capomulin  Female           3          17          0
# 20       x401    Capomulin  Female          16          15          0
# 30       m601    Capomulin    Male          22          17          0
# 40       g791     Ramicane    Male          11          16          0
# ...       ...          ...     ...         ...         ...        ...
# 1858     z314     Stelasyn  Female          21          28          0
# 1860     z435     Propriva  Female          12          26          0
# 1863     z581    Infubinol  Female          24          25          0
# 1873     z795     Naftisol  Female          13          29          0
# 1883     z969     Naftisol    Male           9          30          0
#
#       Tumor Volume (mm3)  Metastatic Sites
# 0                   45.0                 0
# ...

# %%
# Checking the number of mice in the clean DataFrame.
mouse_count = clean_mouse_df["Mouse ID"].count()
mouse_count
# Out:
# 249

# %% [markdown]
# ## Summary Statistics

# %%
# Generate a summary statistics table of mean, median, variance, standard deviation, and SEM of the tumor volume for each regimen

# This method is the most straighforward, creating multiple series and putting them all together at the end.
mean = combined_mouse_df.groupby('Drug Regimen')['Tumor Volume (mm3)'].mean()
median = combined_mouse_df.groupby('Drug Regimen')['Tumor Volume (mm3)'].median()
variance = combined_mouse_df.groupby('Drug Regimen')['Tumor Volume (mm3)'].var()
standard_dv = combined_mouse_df.groupby('Drug Regimen')['Tumor Volume (mm3)'].std()
sem = combined_mouse_df.groupby('Drug Regimen')['Tumor Volume (mm3)'].sem()

summary_mouse_df = pd.DataFrame({"Mean": mean, "Median": median, "Variance": variance, "Standard Deviation": standard_dv, "SEM": sem})
summary_mouse_df
# Out:
#                    Mean     Median   Variance  Standard Deviation       SEM
# Drug Regimen
# Capomulin     40.675741  41.557809  24.947764            4.994774  0.329346
# Ceftamin      52.591172  51.776157  39.290177            6.268188  0.469821
# Infubinol     52.884795  51.820584  43.128684            6.567243  0.492236
# Ketapril      55.235638  53.698743  68.553577            8.279709  0.603860
# Naftisol      54.331565  52.509285  66.173479            8.134708  0.596466
# Placebo       54.033581  52.288934  61.168083            7.821003  0.581331
# Propriva      52.322552  50.854632  42.351070            6.507770  0.512884
# Ramicane      40.216745  40.673236  23.486704            4.846308  0.320955
# Stelasyn      54.233149  52.431737  59.450562            7.710419  0.573111
# Zoniferol     53.236507  51.818479  48.533355            6.966589  0.516398

# %% [markdown]
# ## Bar and Pie Charts

# %%
# Generate a bar plot showing the total number of mice for each treatment throughout the course of the study using pandas. 
drug_data = pd.DataFrame(combined_mouse_df.groupby(["Drug Regimen"]).count()).reset_index()

drugs_df = drug_data[["Drug Regimen", "Mouse ID"]]
drugs_df = drugs_df.set_index("Drug Regimen")

# %%
# Generate a bar plot showing the total number of mice for each treatment throughout the course of the study using pyplot.
drugs_df.plot(kind="bar", figsize=(10,3))

plt.title("Drug Treatment Count")
plt.ylabel("Count")
plt.show()

# %%
# Generate a pie plot showing the distribution of female versus male mice using pandas

# %%
# Generate a pie plot showing the distribution of female versus male mice using pyplot
gender_df = pd.DataFrame(combined_mouse_df.groupby(["Sex"]).count()).reset_index()
gender_df.head()
# Out:
#       Sex  Mouse ID  Drug Regimen  Age_months  Weight (g)  Timepoint  \
# 0  Female       935           935         935         935        935
# 1    Male       958           958         958         958        958
#
#    Tumor Volume (mm3)  Metastatic Sites
# 0                 935               935
# 1                 958               958

# %%
# Filter the DataFrame
gender_df = gender_df[["Sex","Mouse ID"]]
gender_df.head()
# Out:
#       Sex  Mouse ID
# 0  Female       935
# 1    Male       958

# %%
#Pie Chart Data
labels = "Female", "Male"
gender_count = [935,958]
colors = ["pink", "blue"]
explode = (0.1,0)

# %%
# Create a pie chart based upon the above data
plt.pie(gender_count, labels=labels, colors=colors, explode=explode,
        autopct="%1.1f%%", shadow=True, startangle=90)
plt.title("Male & Female Mice Percentage")

# Create axes which are equal so we have a perfect circle
plt.axis("equal")
plt.show()

# %% [markdown]
# ## Quartiles, Outliers and Boxplots

# %%
# Calculate the final tumor volume of each mouse across four of the treatment regimens:  
# Capomulin, Ramicane, Infubinol, and Ceftamin

# %%
all_duplicate_rows.head()
# Out:
#   Mouse ID Drug Regimen   Sex  Age_months  Weight (g)  Timepoint  \
# 1     k403     Ramicane  Male          21          16          5
# 2     k403     Ramicane  Male          21          16         10
# 3     k403     Ramicane  Male          21          16         15
# 4     k403     Ramicane  Male          21          16         20
# 5     k403     Ramicane  Male          21          16         25
#
#    Tumor Volume (mm3)  Metastatic Sites
# 1           38.825898                 0
# 2           35.014271                 1
# 3           34.223992                 1
# 4           32.997729                 1
# 5           33.464577                 1

# %%
# Sort data by Drug Regime, Mouse ID and Timepoint
sorted_df = all_duplicate_rows.sort_values(["Drug Regimen", "Mouse ID", "Timepoint"], ascending=True)
# Select final volume of each mouse 
max_df = sorted_df.loc[sorted_df["Timepoint"] == 45]
max_df.head().reset_index()
# Out:
#    index Mouse ID Drug Regimen     Sex  Age_months  Weight (g)  Timepoint  \
# 0    309     b128    Capomulin  Female           9          22         45
# 1    299     b742    Capomulin    Male           7          21         45
# 2    244     g288    Capomulin    Male           3          19         45
# 3    360     g316    Capomulin  Female          22          22         45
# 4    440     i557    Capomulin  Female           1          24         45
#
#    Tumor Volume (mm3)  Metastatic Sites
# 0           38.982878                 2
# 1           38.939633                 0
# 2           37.074024                 1
# 3           40.159220                 2
# 4           47.685963                 1

# %%
# Select data for Capomulin regimen and reset index
cap_data_df = max_df[max_df['Drug Regimen'].isin(['Capomulin'])]
cap_data_df.head().reset_index()
# Out:
#    index Mouse ID Drug Regimen     Sex  Age_months  Weight (g)  Timepoint  \
# 0    309     b128    Capomulin  Female           9          22         45
# 1    299     b742    Capomulin    Male           7          21         45
# 2    244     g288    Capomulin    Male           3          19         45
# 3    360     g316    Capomulin  Female          22          22         45
# 4    440     i557    Capomulin  Female           1          24         45
#
#    Tumor Volume (mm3)  Metastatic Sites
# 0           38.982878                 2
# 1           38.939633                 0
# 2           37.074024                 1
# 3           40.159220                 2
# 4           47.685963                 1

# %%
# Convert column "Tumor Volume" of the Capomulin regimen into a dataframe object
cap_list = cap_data_df.sort_values(["Tumor Volume (mm3)"], ascending=True).reset_index()
cap_list = cap_list["Tumor Volume (mm3)"]
cap_list
# Out:
# 0     23.343598
# 1     28.430964
# 2     28.484033
# 3     31.023923
# 4     31.896238
# 5     32.377357
# 6     33.329098
# 7     34.455298
# 8     36.041047
# 9     37.074024
# 10    37.311846
# 11    38.125164
# 12    38.846876
# 13    38.939633
# 14    38.982878
# 15    40.159220
# 16    40.658124
# 17    40.728578
# 18    41.483008
# 19    41.581521
# 20    47.685963
# Name: Tumor Volume (mm3), dtype: float64

# %%
# Use pandas to give quartile calculations
quartiles = cap_list.quantile([.25,.5,.75])
lowerq = quartiles[0.25]
upperq = quartiles[0.75]
iqr = upperq-lowerq

print(f"The lower quartile of temperatures is: {lowerq}")
print(f"The upper quartile of temperatures is: {upperq}")
print(f"The interquartile range of temperatures is: {iqr}")
print(f"The the median of temperatures is: {quartiles[0.5]} ")

lower_bound = lowerq - (1.5*iqr)
upper_bound = upperq + (1.5*iqr)
print(f"Values below {lower_bound} could be outliers.")
print(f"Values above {upper_bound} could be outliers.")
# Out:
# The lower quartile of temperatures is: 32.37735684
# The upper quartile of temperatures is: 40.1592203
# The interquartile range of temperatures is: 7.781863460000004
# The the median of temperatures is: 37.31184577
# Values below 20.70456164999999 could be outliers.
# Values above 51.83201549 could be outliers.

# %%
# Generate a box plot of the final tumor volume of each mouse across four regimens of interest
fig1, ax1 = plt.subplots()
ax1.set_title("Final Tumor Volume in Capomulin Regimen")
ax1.set_ylabel("Final Tumor Volume (mm3)")
ax1.boxplot(cap_list)
plt.show()

# %%
# Calculate the final tumor volume of each mouse in the Ramicane regimen:

#Select data for Ramicane regimen and reset index
ram_data_df  = max_df[max_df['Drug Regimen'].isin(['Ramicane'])]
ram_data_df .head().reset_index()
# Out:
#    index Mouse ID Drug Regimen     Sex  Age_months  Weight (g)  Timepoint  \
# 0    327     a411     Ramicane    Male           3          22         45
# 1    430     a444     Ramicane  Female          10          25         45
# 2    214     a520     Ramicane    Male          13          21         45
# 3    174     a644     Ramicane  Female           7          17         45
# 4    154     c758     Ramicane    Male           9          17         45
#
#    Tumor Volume (mm3)  Metastatic Sites
# 0           38.407618                 1
# 1           43.047543                 0
# 2           38.810366                 1
# 3           32.978522                 1
# 4           33.397653                 1

# %%
# Convert column "Tumor Volume" of the Ramicane regimen into a dataframe object
ram_list = ram_data_df.sort_values(["Tumor Volume (mm3)"], ascending=True).reset_index()
ram_list = ram_list["Tumor Volume (mm3)"]
ram_list
# Out:
# 0     22.050126
# 1     29.128472
# 2     30.276232
# 3     30.564625
# 4     30.638696
# 5     31.095335
# 6     31.560470
# 7     32.978522
# 8     33.397653
# 9     33.562402
# 10    36.134852
# 11    36.374510
# 12    37.225650
# 13    37.311236
# 14    38.407618
# 15    38.810366
# 16    40.659006
# 17    40.667713
# 18    43.047543
# 19    45.220869
# Name: Tumor Volume (mm3), dtype: float64

# %%
# Use pandas to give quartile calculations
quartiles = ram_list.quantile([.25,.5,.75])
lowerq = quartiles[0.25]
upperq = quartiles[0.75]
iqr = upperq-lowerq

print(f"The lower quartile of temperatures is: {lowerq}")
print(f"The upper quartile of temperatures is: {upperq}")
print(f"The interquartile range of temperatures is: {iqr}")
print(f"The the median of temperatures is: {quartiles[0.5]} ")

lower_bound = lowerq - (1.5*iqr)
upper_bound = upperq + (1.5*iqr)
print(f"Values below {lower_bound} could be outliers.")
print(f"Values above {upper_bound} could be outliers.")
# Out:
# The lower quartile of temperatures is: 30.981175224999998
# The upper quartile of temperatures is: 38.508305307499995
# The interquartile range of temperatures is: 7.527130082499998
# The the median of temperatures is: 34.848627300000004
# Values below 19.690480101250003 could be outliers.
# Values above 49.79900043124999 could be outliers.

# %%
# Generate a box plot of the final tumor volume of each mouse across four regimens of interest
fig1, ax1 = plt.subplots()
ax1.set_title("Final Tumor Volume in Ramicane Regimen")
ax1.set_ylabel("Final Tumor Volume (mm3)")
ax1.boxplot(ram_list)
plt.show()

# %%
# Calculate the final tumor volume of each mouse in the Infubinol regimen:

#Select data for Ramicane regimen and reset index
Inf_data_df  = max_df[max_df['Drug Regimen'].isin(['Infubinol'])]
Inf_data_df .head().reset_index()
# Out:
#    index Mouse ID Drug Regimen     Sex  Age_months  Weight (g)  Timepoint  \
# 0    463     a203    Infubinol  Female          20          23         45
# 1    473     a251    Infubinol  Female          21          25         45
# 2    540     a685    Infubinol    Male           8          30         45
# 3    637     c139    Infubinol    Male          11          28         45
# 4    800     e476    Infubinol    Male          23          26         45
#
#    Tumor Volume (mm3)  Metastatic Sites
# 0           67.973419                 2
# 1           65.525743                 1
# 2           66.083066                 3
# 3           72.226731                 2
# 4           62.435404                 1

# %%
# Convert column "Tumor Volume" of the Infubinol regimen into a dataframe object
Inf_list = Inf_data_df.sort_values(["Tumor Volume (mm3)"], ascending=True).reset_index()
Inf_list = Inf_list["Tumor Volume (mm3)"]
Inf_list
# Out:
# 0    60.918767
# 1    62.435404
# 2    62.754451
# 3    65.525743
# 4    66.083066
# 5    66.196912
# 6    67.685569
# 7    67.973419
# 8    72.226731
# Name: Tumor Volume (mm3), dtype: float64

# %%
# Use pandas to give quartile calculations
quartiles = Inf_list.quantile([.25,.5,.75])
lowerq = quartiles[0.25]
upperq = quartiles[0.75]
iqr = upperq-lowerq

print(f"The lower quartile of temperatures is: {lowerq}")
print(f"The upper quartile of temperatures is: {upperq}")
print(f"The interquartile range of temperatures is: {iqr}")
print(f"The the median of temperatures is: {quartiles[0.5]} ")

lower_bound = lowerq - (1.5*iqr)
upper_bound = upperq + (1.5*iqr)
print(f"Values below {lower_bound} could be outliers.")
print(f"Values above {upper_bound} could be outliers.")
# Out:
# The lower quartile of temperatures is: 62.75445141
# The upper quartile of temperatures is: 67.68556862
# The interquartile range of temperatures is: 4.9311172099999965
# The the median of temperatures is: 66.08306589
# Values below 55.35777559500001 could be outliers.
# Values above 75.08224443499999 could be outliers.

# %%
# Generate a box plot of the final tumor volume of each mouse across four regimens of interest
fig1, ax1 = plt.subplots()
ax1.set_title("Final Tumor Volume in Infubinol Regimen")
ax1.set_ylabel("Final Tumor Volume (mm3)")
ax1.boxplot(Inf_list)
plt.show()

# %%
# Calculate the final tumor volume of each mouse in the Ceftamin regimen:

#Select data for Ramicane regimen and reset index
Cef_data_df  = max_df[max_df['Drug Regimen'].isin(['Ceftamin'])]
Cef_data_df .head().reset_index()
# Out:
#    index Mouse ID Drug Regimen     Sex  Age_months  Weight (g)  Timepoint  \
# 0    493     a275     Ceftamin  Female          20          28         45
# 1    993     j296     Ceftamin  Female          24          30         45
# 2   1033     k210     Ceftamin    Male          15          28         45
# 3   1112     l471     Ceftamin  Female           7          28         45
# 4   1132     l661     Ceftamin    Male          18          26         45
#
#    Tumor Volume (mm3)  Metastatic Sites
# 0           62.999356                 3
# 1           61.849023                 3
# 2           68.923185                 3
# 3           67.748662                 1
# 4           59.851956                 3

# %%
# Convert column "Tumor Volume" of the Infubinol regimen into a dataframe object
Cef_list = Cef_data_df.sort_values(["Tumor Volume (mm3)"], ascending=True).reset_index()
Cef_list = Cef_list["Tumor Volume (mm3)"]
Cef_list
# Out:
# 0     59.741901
# 1     59.851956
# 2     61.386660
# 3     61.433892
# 4     61.849023
# 5     62.999356
# 6     64.299830
# 7     64.634949
# 8     64.729837
# 9     67.527482
# 10    67.748662
# 11    68.594745
# 12    68.923185
# Name: Tumor Volume (mm3), dtype: float64

# %%
# Use pandas to give quartile calculations
quartiles = Cef_list.quantile([.25,.5,.75])
lowerq = quartiles[0.25]
upperq = quartiles[0.75]
iqr = upperq-lowerq

print(f"The lower quartile of temperatures is: {lowerq}")
print(f"The upper quartile of temperatures is: {upperq}")
print(f"The interquartile range of temperatures is: {iqr}")
print(f"The the median of temperatures is: {quartiles[0.5]} ")

lower_bound = lowerq - (1.5*iqr)
upper_bound = upperq + (1.5*iqr)
print(f"Values below {lower_bound} could be outliers.")
print(f"Values above {upper_bound} could be outliers.")
# Out:
# The lower quartile of temperatures is: 61.43389223
# The upper quartile of temperatures is: 67.52748237
# The interquartile range of temperatures is: 6.093590140000003
# The the median of temperatures is: 64.29983003
# Values below 52.29350701999999 could be outliers.
# Values above 76.66786758 could be outliers.

# %%
# Generate a box plot of the final tumor volume of each mouse across four regimens of interest
fig1, ax1 = plt.subplots()
ax1.set_title("Final Tumor Volume in Ceftamin Regimen")
ax1.set_ylabel("Final Tumor Volume (mm3)")
ax1.boxplot(Cef_list)
plt.show()

# %%
# Generate a box plot of the final tumor volume of each mouse across four regimens of interest

# %% [markdown]
# ## Line and Scatter Plots

# %%
# Generate a line plot of time point versus tumor volume for a mouse treated with Capomulin
capomulin_df = combined_mouse_df.loc[combined_mouse_df["Drug Regimen"] == "Capomulin"]
capomulin_df = capomulin_df.reset_index()
capomulin_df.head()
# Out:
#    index Mouse ID Drug Regimen     Sex  Age_months  Weight (g)  Timepoint  \
# 0     10     s185    Capomulin  Female           3          17          0
# 1     11     s185    Capomulin  Female           3          17          5
# 2     12     s185    Capomulin  Female           3          17         10
# 3     13     s185    Capomulin  Female           3          17         15
# 4     14     s185    Capomulin  Female           3          17         20
#
#    Tumor Volume (mm3)  Metastatic Sites
# 0           45.000000                 0
# 1           43.878496                 0
# 2           37.614948                 0
# 3           38.177232                 0
# 4           36.866876                 0

# %%
# Select data of a single mouse
cap_single_df = capomulin_df.loc[capomulin_df["Mouse ID"] == "s185"]
cap_single_df
# Out:
#    index Mouse ID Drug Regimen     Sex  Age_months  Weight (g)  Timepoint  \
# 0     10     s185    Capomulin  Female           3          17          0
# 1     11     s185    Capomulin  Female           3          17          5
# 2     12     s185    Capomulin  Female           3          17         10
# 3     13     s185    Capomulin  Female           3          17         15
# 4     14     s185    Capomulin  Female           3          17         20
# 5     15     s185    Capomulin  Female           3          17         25
# 6     16     s185    Capomulin  Female           3          17         30
# 7     17     s185    Capomulin  Female           3          17         35
# 8     18     s185    Capomulin  Female           3          17         40
# 9     19     s185    Capomulin  Female           3          17         45
#
#    Tumor Volume (mm3)  Metastatic Sites
# 0           45.000000                 0
# 1           43.878496                 0
# ...

# %%
# Selecting only 2 columns
cap_single_df = cap_single_df.loc[:, ["Timepoint", "Tumor Volume (mm3)"]]
#capomulin_df.index
#Reset the index
cap_single_df = cap_single_df.reset_index(drop=True)
# Generate a line plot of time point versus tumor volume for a mouse treated with Capomulin
cap_single_df.set_index('Timepoint').plot(figsize=(10, 8), linewidth=2.5, color='purple')

# %%
# Generate a scatter plot of mouse weight versus average tumor volume for the Capomulin regimen
capomulin_df.head()
# Out:
#    index Mouse ID Drug Regimen     Sex  Age_months  Weight (g)  Timepoint  \
# 0     10     s185    Capomulin  Female           3          17          0
# 1     11     s185    Capomulin  Female           3          17          5
# 2     12     s185    Capomulin  Female           3          17         10
# 3     13     s185    Capomulin  Female           3          17         15
# 4     14     s185    Capomulin  Female           3          17         20
#
#    Tumor Volume (mm3)  Metastatic Sites
# 0           45.000000                 0
# 1           43.878496                 0
# 2           37.614948                 0
# 3           38.177232                 0
# 4           36.866876                 0

# %%
#Arrange data into 3 columns
weight_tumor_df = capomulin_df.loc[:, ["Mouse ID", "Weight (g)", "Tumor Volume (mm3)"]]
weight_tumor_df.head()
# Out:
#   Mouse ID  Weight (g)  Tumor Volume (mm3)
# 0     s185          17           45.000000
# 1     s185          17           43.878496
# 2     s185          17           37.614948
# 3     s185          17           38.177232
# 4     s185          17           36.866876

# %%
# Calculate average tumor volume for each mouse in the Capomulin regimen
average_tumor = pd.DataFrame(weight_tumor_df.groupby(["Mouse ID", "Weight (g)"])["Tumor Volume (mm3)"].mean()).reset_index()
average_tumor.head()
# Out:
#   Mouse ID  Weight (g)  Tumor Volume (mm3)
# 0     b128          22           41.963636
# 1     b742          21           40.083699
# 2     f966          17           36.505973
# 3     g288          19           41.990097
# 4     g316          22           44.613344

# %%
# Generate a scatter plot of mouse weight versus average tumor volume for the Capomulin regimen
average_tumor.plot(kind="scatter", x="Weight (g)", y="Tumor Volume (mm3)", grid=True, figsize=(4,4), title="Weight vs. Tumor Volume (mm3)")
plt.show()

# %% [markdown]
# ## Correlation and Regression

# %%
# Calculate the correlation coefficient and linear regression model 
# for mouse weight and average tumor volume for the Capomulin regimen
